# %% [markdown]
# # Neural Decoder: Model Comparison
# Decoding 2D motor velocity from 192-channel neural recordings across 312 sessions.

# %% [markdown]
# R² scores comparison table

# %%
import pandas as pd
from project_brain_decoder.config import get_project_root

df = pd.read_csv(get_project_root() / "results" / "r2_scores.csv")
df

# %% [markdown]
# ### Predicted vs Actual Velocity

# %%
from IPython.display import Image
import matplotlib.pyplot as plt

models = ["ridge", "tcn", "gru", "kalman"]
for model in models:
    print(model)
    display(Image(get_project_root() / "results" / "plots" / f"{model}_pred_vs_actual.jpg"))
